# %%
empids=[1,2,3]

# %%
type(empids)
# Out:
# list

# %%
import numpy as np

# %%
arr1=np.array([101,102,103])

# %%
arr1
# Out:
# array([101, 102, 103])

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr1.shape
# Out:
# (3,)

# %%
arr2=np.array([[1,2],[3,4]])

# %%
arr2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr2.shape
# Out:
# (2, 2)

# %%
arr4=np.array([[1,3,4],[4,5]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 arr4=np.array([[1,3,4],[4,5]])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
arr3=np.array([[[1,2,3],[5,6,7]]])

# %%
arr3
# Out:
# array([[[1, 2, 3],
#         [5, 6, 7]]])

# %%
arr3.shape
# Out:
# (1, 2, 3)

# %%
arr1
# Out:
# array([101, 102, 103])

# %%
arr1[0]
# Out:
# np.int64(101)

# %%
arr1[1]
# Out:
# np.int64(102)

# %%
arr1[2]
# Out:
# np.int64(103)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
arr2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr2[0,0]
# Out:
# np.int64(1)

# %%
arr2[0,1]
# Out:
# np.int64(2)

# %%
arr2[1,0]
# Out:
# np.int64(3)

# %%
arr2[1,1]
# Out:
# np.int64(4)

# %%
arr3
# Out:
# array([[[1, 2, 3],
#         [5, 6, 7]]])

# %%
arr3[0 ,0 ,0]
# Out:
# np.int64(1)

# %%
arr3[0,0]
# Out:
# array([1, 2, 3])

# %%
arr3[0]
# Out:
# array([[1, 2, 3],
#        [5, 6, 7]])

# %%
arr3[0,1,0]
# Out:
# np.int64(5)

# %% [markdown]
# # ![image.png](attachment:image.png)
